# %% [markdown]
#  # Ionome - LCMS package

# %%
# import path
from src.ionome_core import Ionome

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
first = Ionome(run_id="SL005", samples="samples.yaml")
# Out:
# >[2025-11-17 06:11:16][Ionome.__init__]
# 	Initializing run ID SL005 for analysis

# %%
first.load_data()
# Out:
# >[2025-11-17 06:11:44][Ionome.load_data]
# 	> Loading spectra data for sample SL005_EA_1...
# 	 Parsing 010__20201112__SL005__EA_Blank__nosplit.mzML ...
# 	 Caching spectra data
# 	> Loading spectra data for sample SL005_EA_2...
# 	 Parsing 011__20201112__SL005__EA_Blank__nosplit.mzML ...
# 	 Caching spectra data
# 	> Loading spectra data for sample SL005_MB_1...
# 	 Parsing 012__20201112__SL005__MB1__nosplit.mzML ...
# 	 Caching spectra data
# 	> Loading spectra data for sample SL005_BHI_1...
# 	 Parsing 013__20201112__SL005__BHI_C__nosplit.mzML ...
# 	 Caching spectra data
# 	> Loading spectra data for sample SL005_EL_24hr...
# 	 Parsing 014__20201112__SL005__EL_C_24hr__nosplit.mzML ...
# 	 Caching spectra data
# 	> Loading spectra data for sample SL005_EL_48hr...
# 	 Parsing 015__20201112__SL005__EL_C_48hr__nosplit.mzML ...
# 	 Caching spectra data
# 	> Loading spectra data for sample SL005_EL_72hr...
# 	 Parsing 016__20201112__SL005__EL_C_72hr__nosplit.mzML ...
# ...

# %%
first_raw_df = first.data['SL005_EL_24hr'][first.data['SL005_EL_24hr']['mz'] == 50.049999]

# %%
first_raw_df
# Out:
#          ms_level  scan_id  retention_time     intensity         mz
# 4417            1        8        4.337317  18393.398438  50.049999
# 14350           1       24        4.437400  16615.837891  50.049999
# 16236           1       27        4.456167  19893.125000  50.049999
# 19368           1       32        4.487450  16296.346680  50.049999
# 19991           1       33        4.493700  17163.439453  50.049999
# ...           ...      ...             ...           ...        ...
# 1653486         1     2774       21.639733    361.708954  50.049999
# 1660359         1     2785       21.708550    419.882446  50.049999
# 1692137         1     2836       22.027567    479.565765  50.049999
# 1717813         1     2877       22.284033    397.446289  50.049999
# 1721556         1     2883       22.321567    508.928070  50.049999
#
# [294 rows x 5 columns]

# %%
first_raw_df = first.data['SL005_EL_24hr']
first_raw_df
# Out:
#          ms_level  scan_id  retention_time     intensity          mz
# 0               1        1        4.293533  24314.119141   51.040001
# 1               1        1        4.293533  53341.289062   52.060001
# 2               1        1        4.293533   6819.981934   53.049999
# 3               1        1        4.293533   1238.951294   53.980000
# 4               1        1        4.293533   4658.718750   55.020000
# ...           ...      ...             ...           ...         ...
# 1792196         1     2990       22.990900      1.795156  596.169983
# 1792197         1     2990       22.990900      1.711735  597.260010
# 1792198         1     2990       22.990900      3.206854  597.969971
# 1792199         1     2990       22.990900      1.128073  598.570007
# 1792200         1     2990       22.990900      3.180370  599.280029
#
# [1792201 rows x 5 columns]

# %%
first.extract_xic()
# Out:
# >[2025-11-17 06:21:06][Ionome.extract_xic]
# 	> Loading XIC cached data for sample(s) ['SL005_EA_1', 'SL005_EA_2', 'SL005_MB_1', 'SL005_BHI_1', 'SL005_EL_24hr', 'SL005_EL_48hr', 'SL005_EL_72hr', 'SL005_MB_2', 'SL005_BHI_2', 'SL005_EA_3']
# <Ionome>
# (run_id = SL005
# ...
