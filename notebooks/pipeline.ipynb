# %% [markdown]
#  # Ionome - LCMS package

# %%
# import path
from src.ionome_core import Ionome

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
first = Ionome(run_id="SL005", samples="samples.yaml")
# Out:
# >[2025-11-17 05:30:18][Ionome.__init__]
# 	Initializing run ID SL005 for analysis

# %%
first.load_data()
# Out:
# >[2025-11-17 05:29:21][Ionome.load_data]
# 	> Loading spectra data for sample SL005_EA_1...
# 	 Parsing 010__20201112__SL005__EA_Blank__nosplit.mzML ...
# 	 Caching spectra data
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 first.load_data()
#
# File ~/Desktop/test_ionome/src/ionome_core.py:79, in Ionome.load_data(self, **kwargs)
#      76 sleep(1)
#      78 parser = MzmlParser(self.sample_list[sample], rerun = self.rerun, **parser_cfg)
# ---> 79 df_data = parser.parse_or_load_mzml(**kwargs)
#      80 self.data[sample] = df_data
#
# File ~/Desktop/test_ionome/src/preprocess.py:60, in MzmlParser.parse_or_load_mzml(self, **kwargs)
#      58 # Save to Parquet, reuse if 'rerun' is False
#      59 print(f"\t Caching spectra data")
# ---> 60 master_df.to_parquet(parquet_path, index=False)
#      62 return master_df
#
# ...

# %%
first_raw_df = first.data['SL005_24hr'][first.data['SL005_24hr']['mz'] == 50.049999]

# %%
first.extract_xic()
# Out:
# >[2025-11-11 03:40:45][Ionome.extract_xic]
# 	>Extracting mz targets for analysis...
# 	p-coumerate: 163.04007
# 	urocanate: 137.03565
# 	caffeate: 179.03498
# 	SL005_24hr -
# 	SL005_48hr -
# 	SL005_72hr -
